# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(cities)
# Out:
# ['kamenskoye', 'vaini', 'manta', 'albany', 'clyde river', 'taltal', 'hilo', 'constitucion', 'mlowo', 'mount isa', 'tateyama', 'merke', 'williston', 'dharchula', 'souillac', 'arnoldstein', 'urumqi', 'new norfolk', 'zavodskoy', 'la ronge', 'tasiilaq', 'inderborskiy', 'esperance', 'rikitea', 'klaksvik', 'kimbe', 'asau', 'maceio', 'tiarei', 'bathsheba', 'kodiak', 'ushuaia', 'kapaa', 'maragogi', 'port alfred', 'hami', 'wanaka', 'mataura', 'atuona', 'cidreira', 'khatanga', 'airai', 'tumannyy', 'sungairaya', 'punta arenas', 'bluff', 'hihifo', 'mar del plata', 'attawapiskat', 'pangnirtung', 'vaitupu', 'avera', 'vardo', 'kanallakion', 'miandrivazo', 'homer', 'lebu', 'amderma', 'sao filipe', 'butaritari', 'chicama', 'dikson', 'thompson', 'bukama', 'cape town', 'nanortalik', 'umzimvubu', 'namibe', 'qaanaaq', 'derzhavinsk', 'joutseno', 'sinnamary', 'grand river south east', 'inhambane', 'puerto ayora', 'busselton', 'mahebourg', 'victor harbor', 'chuy', 'chokurdakh', 'bredasdorp', 'castro', 'igrim', 'guerrero negro', 'port macquarie', 'nevers', 'mgachi', 'san cristobal', 'palabuhanratu', 'taolanaro', 'hope', 'munster', 'ozernovskiy', 'hovd', 'tura', 'hobart', 'severo-kurilsk', 'saint pete beach', 'kangaatsiaq', 'canaries', 'bhinmal', 'kavaratti', 'kirksville', 'ilulissat', 'bethel', 'whitianga', 'coquimbo', 'olafsvik', 'north augusta', 'longyearbyen', 'sao joao da barra', 'seoul', 'tuktoyaktuk', 'dryden', 'tiksi', 'los llanos de aridane', 'kaitangata', 'boyolangu', 'nieuwkoop', 'avarua', 'warqla', 'samusu', 'berbera', 'miri', 'jamestown', 'nguiu', 'lake wales', 'geraldton', 'verkhnedneprovskiy', 'shilka', 'bowmore', 'yulara', 'morgaushi', 'biscarrosse', 'hermanus', 'torbay', 'houma', 'lompoc', 'saint-philippe', 'palmer', 'praia', 'katsuura', 'isangel', 'gazanjyk', 'itarema', 'poum', 'athabasca', 'louisbourg', 'ponta delgada', 'cabo san lucas', 'labuhan', 'partizanskoye', 'east london', 'yertsevo', 'uk', 'nha trang', 'grindavik', 'saleaula', 'kasese', 'burgeo', 'abu samrah', 'denpasar', 'chernyshevskiy', 'manhattan', 'warrnambool', 'carnarvon', 'vaitape', 'veraval', 'nouadhibou', 'esik', 'maues', 'azimur', 'iquique', 'bollnas', 'lazaro cardenas', 'georgetown', 'takoradi', 'banda aceh', 'hithadhoo', 'salalah', 'saskylakh', 'cherskiy', 'sao domingos', 'japura', 'gat', 'gillette', 'saint george', 'kruisfontein', 'lujan', 'flin flon', 'balsas', 'barentsburg', 'walvis bay', 'paradwip', 'faanui', 'sitka', 'atar', 'turayf', 'del rio', 'ribeira grande', 'yellowknife', 'kiruna', 'ukiah', 'vila', 'lincoln', 'bennington', 'masvingo', 'roald', 'celendin', 'port elizabeth', 'meulaboh', 'baglung', 'lagoa', 'belmonte', 'kinlochleven', 'broome', 'manggar', 'petatlan', 'aldan', 'nizhneyansk', 'deputatskiy', 'illoqqortoormiut', 'gornopravdinsk', 'theunissen', 'verkhoyansk', 'lolua', 'witrivier', 'tessalit', 'yialos', 'marsa matruh', 'madaoua', 'contai', 'luderitz', 'zaraza', 'zolotinka', 'jacareacanga', 'russkaya polyana', 'fort nelson', 'nurota', 'bambous virieux', 'valparaiso', 'barrow', 'hamilton', 'vostok', 'akyab', 'iqaluit', 'half moon bay', 'griffith', 'thinadhoo', 'beloha', 'shimoda', 'vila franca do campo', 'hambantota', 'dingle', 'safwah', 'belushya guba', 'khormuj', 'san quintin', 'anadyr', 'saleilua', 'arlit', 'provideniya', 'yenagoa', 'norman wells', 'yuzhno-yeniseyskiy', 'dombarovskiy', 'cockburn town', 'bedesa', 'balakliya', 'mehamn', 'codrington', 'comodoro rivadavia', 'labutta', 'nikolskoye', 'sentyabrskiy', 'meaford', 'turukhansk', 'bubaque', 'nome', 'pukhrayan', 'gondanglegi', 'tilichiki', 'kantunilkin', 'darhan', 'shingu', 'fare', 'baghdad', 'newport', 'san patricio', 'ponta do sol', 'chaozhou', 'muli', 'beringovskiy', 'saldanha', 'calama', 'kahului', 'moussoro', 'pontarlier', 'oranjestad', 'narsaq', 'hastings', 'amarante do maranhao', 'leh', 'rawannawi', 'fairbanks', 'grand centre', 'haibowan', 'rungata', 'mkuranga', 'nhulunbuy', 'pevek', 'mount gambier', 'kulhudhuffushi', 'magan', 'lata', 'kerki', 'lockhart', 'burica', 'vitim', 'rio gra ...

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=35fe25205f07407053122f2846074615

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | arlit
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | nioro
# Processing Record 5 of Set 1 | varkaus
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | akyab
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | katsuura
# Processing Record 10 of Set 1 | sao sebastiao
# Processing Record 11 of Set 1 | sitka
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | turukhansk
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | beaufort
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | borlange
# City not found. Skipping...
# Processing Record 30 of Set 1 | harnosand
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | erenhot
# Processing Record 33 of Set 1 | rongcheng
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | nioki
# Processing Record 36 of Set 1 | mongo
# Processing Record 37 of Set 1 | sisimiut
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | rawson
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | mehamn
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | panzhihua
# Processing Record 46 of Set 1 | kavaratti
# Processing Record 47 of Set 1 | bellavista
# Processing Record 48 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | ishigaki
# Processing Record 1 of Set 2 | kurilsk
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | kahului
# Processing Record 7 of Set 2 | coihaique
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | kilindoni
# Processing Record 10 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 2 | puerto escondido
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | juneau
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | constitucion
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | port macquarie
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | zhanaozen
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | berlevag
# Processing Record 24 of Set 2 | williamsport
# Processing Record 25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 2 | coquimbo
# Processing Record 27 of Set 2 | saint-pierre
# Processing Record 28 of Set 2 | boueni
# Processing Record 29 of Set 2 | port shepstone
# Processing Record 30 of Set 2 | nagato
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | seoul
# Processing Record 33 of Set 2 | souillac
# Processing Record 34 of Set 2 | ilulissat
# Processing Record 35 of Set 2 | dien bien
# City not found. Skipping...
# Processing Record 36 of Set 2 | vzmorye
# Processing Record 37 of Set 2 | ahipara
# Processing Record 38 of Set 2 | sao felix do xingu
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | udachnyy
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | bathsheba
# Processing Record 43 of Set 2 | pangnirtung
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | camopi
# Processing Record 46 of Set 2 | zyryanka
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 3 | beringovskiy
# Processing Record 2 of Set 3 | emerald
# Processing Record 3 of Set 3 | zhezkazgan
# Processing Record 4 of Set 3 | kristallopiyi
# City not found. Skipping...
# Processing Record 5 of Set 3 | egvekinot
# Processing Record 6 of Set 3 | nishihara
# Processing Record 7 of Set 3 | caceres
# Processing Record 8 of Set 3 | ponta do sol
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | hailar
# Processing Record 13 of Set 3 | dwarka
# Processing Record 14 of Set 3 | gat
# Processing Record 15 of Set 3 | cayenne
# Processing Record 16 of Set 3 | christchurch
# Processing Record 17 of Set 3 | ixtapa
# Processing Record 18 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 3 | cidreira
# Processing Record 20 of Set 3 | marystown
# Processing Record 21 of Set 3 | isangel
# Processing Record 22 of Set 3 | hualmay
# Processing Record 23 of Set 3 | nome
# Processing Record 24 of Set 3 | tondela
# Processing Record 25 of Set 3 | vila velha
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | rio grande
# Processing Record 28 of Set 3 | saint-augustin
# Processing Record 29 of Set 3 | asau
# Processing Record 30 of Set 3 | ostrovnoy
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | codrington
# Processing Record 33 of Set 3 | khatanga
# Processing Record 34 of Set 3 | nouadhibou
# Processing Record 35 of Set 3 | tautira
# Processing Record 36 of Set 3 | vila franca do campo
# Processing Record 37 of Set 3 | buraydah
# Processing Record 38 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | oriximina
# Processing Record 41 of Set 3 | trelew
# Processing Record 42 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 3 | ulladulla
# Processing Record 44 of Set 3 | puerto del rosario
# Processing Record 45 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | capao da canoa
# Processing Record 48 of Set 3 | beya
# Processing Record 49 of Set 3 | balimo
# City not found. Skipping...
# Processing Record 50 of Set 3 | hamilton
# Processing Record 1 of Set 4 | alexandria
# Processing Record 2 of Set 4 | chopovychi
# Processing Record 3 of Set 4 | sikasso
# Processing Record 4 of Set 4 | kassala
# Processing Record 5 of Set 4 | amalapuram
# Processing Record 6 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | chapada dos guimaraes
# Processing Record 9 of Set 4 | necochea
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | nara
# Processing Record 12 of Set 4 | avera
# Processing Record 13 of Set 4 | bluff
# Processing Record 14 of Set 4 | bantry
# Processing Record 15 of Set 4 | zhuanghe
# Processing Record 16 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | murgab
# Processing Record 19 of Set 4 | tuatapere
# Processing Record 20 of Set 4 | kapaa
# Processing Record 21 of Set 4 | bubaque
# Processing Record 22 of Set 4 | morgan city
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | moron
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | kasongo
# Processing Record 27 of Set 4 | bambous virieux
# Processing Record 28 of Set 4 | port maria
# Processing Record 29 of Set 4 | cherskiy
# Processing Record 30 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 4 | qui nhon
# Processing Record 32 of Set 4 | port-gentil
# Processing Record 33 of Set 4 | korla
# Processing Record 34 of Set 4 | hay river
# Processing Record 35 of Set 4 | kemijarvi
# Processing Record 36 of Set 4 | carnarvon
# Processing Record 37 of Set 4 | malakal
# Processing Record 38 of Set 4 | sobolevo
# Processing Record 39 of Set 4 | port lincoln
# Processing Record 40 of Set 4 | vao
# Processing Record 41 of Set 4 | cervo
# Processing Record 42 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 4 | cururupu
# Processing Record 44 of Set 4 | avarua
# Processing Record 45 of Set 4 | saint-philippe
# Processing Record 46 of Set 4 | xianshuigu
# Processing Record 47 of Set 4 | san andres
# Processing Record 48 of Set 4 | guerrero negro
# Processing Record 49 of Set 4 | boteni
# Processing Record 50 of Set 4 | galle
# Processing Record 1 of Set 5 | daboh
# Processing Record 2 of Set 5 | byron bay
# Processing Record 3 of Set 5 | carnduff
# Processing Record 4 of Set 5 | lorengau
# Processing Record 5 of Set 5 | matamoros
# Processing Record 6 of Set 5 | hami
# Processing Record 7 of Set 5 | nuevo progreso
# Processing Record 8 of Set 5 | kaniama
# Processing Record 9 of Set 5 | kodiak
# Processing Record 10 of Set 5 | qingdao
# Processing Record 11 of Set 5 | foumbot
# Processing Record 12 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 13 of Set 5 | bengkulu
# Processing Record 14 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 5 | palmer
# Processing Record 16 of Set 5 | adrar
# Processing Record 17 of Set 5 | namatanai
# Processing Record 18 of Set 5 | glendive
# Processing Record 19 of Set 5 | los llanos de aridane
# Processing Record 20 of Set 5 | mushie
# Processing Record 21 of Set 5 | mantua
# Processing Record 22 of Set 5 | stephenville
# Processing Record 23 of Set 5 | barra
# Processing Record 24 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 25 of Set 5 | pithapuram
# Processing Record 26 of Set 5 | marathopolis
# City not found. Skipping...
# Processing Record 27 of Set 5 | shellbrook
# Processing Record 28 of Set 5 | pochutla
# Processing Record 29 of Set 5 | poum
# Processing Record 30 of Set 5 | san patricio
# Processing Record 31 of Set 5 | alice springs
# Processing Record 32 of Set 5 | oga
# Processing Record 33 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | luanshya
# Processing Record 35 of Set 5 | mamallapuram
# Processing Record 36 of Set 5 | laguna
# Processing Record 37 of Set 5 | talnakh
# Processing Record 38 of Set 5 | mairipora
# Processing Record 39 of Set 5 | plataiai
# City not found. Skipping...
# Processing Record 40 of Set 5 | nuuk
# Processing Record 41 of Set 5 | torbay
# Processing Record 42 of Set 5 | saldanha
# Processing Record 43 of Set 5 | ancud
# Processing Record 44 of Set 5 | herat
# Processing Record 45 of Set 5 | tasiilaq
# Processing Record 46 of Set 5 | porto novo
# Processing Record 47 of Set 5 | airai
# Processing Record 48 of Set 5 | aklavik
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 50 of Set 5 | te anau
# Processing Record 1 of Set 6 | abu kamal
# Processing Record 2 of Set 6 | nanticoke
# Processing Record 3 of Set 6 | sept-iles
# Processing Record 4 of Set 6 | kayes
# Processing Record 5 of Set 6 | nanortalik
# Processing Record 6 of Set 6 | kolobrzeg
# Processing Record 7 of Set 6 | pemberton
# Processing Record 8 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 6 | achisay
# City not found. Skipping...
# Processing Record 10 of Set 6 | khelyulya
# Processing Record 11 of Set 6 | lima
# Processing Record 12 of Set 6 | arrifes
# Processing Record 13 of Set 6 | calama
# Processing Record 14 of Set 6 | fort nelson
# Processing Record 15 of Set 6 | dakar
# Processing Record 16 of Set 6 | kurumkan
# Processing Record 17 of Set 6 | zamosc
# Processing Record 18 of Set 6 | teguise
# Processing Record 19 of Set 6 | gamba
# Processing Record 20 of Set 6 | portland
# Processing Record 21 of Set 6 | griffith
# Processing Record 22 of Set 6 | broome
# Processing Record 23 of Set 6 | copiapo
# Processing Record 24 of Set 6 | almaznyy
# Processing Record 25 of Set 6 | the valley
# Processing Record 26 of Set 6 | zhigansk
# Processing Record 27 of Set 6 | san policarpo
# Processing Record 28 of Set 6 | aitape
# Processing Record 29 of Set 6 | chapais
# Processing Record 30 of Set 6 | bara
# Processing Record 31 of Set 6 | sedro-woolley
# Processing Record 32 of Set 6 | qaqortoq
# Processing Record 33 of Set 6 | kutum
# Processing Record 34 of Set 6 | moose factory
# Processing Record 35 of Set 6 | portpatrick
# City not found. Skipping...
# Processing Record 36 of Set 6 | antalaha
# Processing Record 37 of Set 6 | shenjiamen
# Processing Record 38 of Set 6 | sorland
# Processing Record 39 of Set 6 | mount isa
# Processing Record 40 of Set 6 | praia da vitoria
# Processing Record 41 of Set 6 | faanui
# Processing Record 42 of Set 6 | tangjiazhuang
# Processing Record 43 of Set 6 | dharmapuri
# Processing Record 44 of Set 6 | gasa
# Processing Record 45 of Set 6 | iquique
# Processing Record 46 of Set 6 | college
# Processing Record 47 of Set 6 | casian
# Processing Record 48 of Set 6 | olafsvik
# Processing Record 49 of Set 6 | french harbor
# Processing Record 50 of Set 6 | laramie
# Processing Record 1 of Set 7 | longyearbyen
# Processing Record 2 of Set 7 | umarga
# Processing Record 3 of Set 7 | fare
# Processing Record 4 of Set 7 | puerto el triunfo
# Processing Record 5 of Set 7 | kalmunai
# Processing Record 6 of Set 7 | cap malheureux
# Processing Record 7 of Set 7 | igarka
# Processing Record 8 of Set 7 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 9 of Set 7 | reporoa
# Processing Record 10 of Set 7 | vanderhoof
# Processing Record 11 of Set 7 | fairbanks
# Processing Record 12 of Set 7 | severomuysk
# Processing Record 13 of Set 7 | coos bay
# Processing Record 14 of Set 7 | bilma
# Processing Record 15 of Set 7 | lhuntshi
# City not found. Skipping...
# Processing Record 16 of Set 7 | hobart
# Processing Record 17 of Set 7 | impfondo
# Processing Record 18 of Set 7 | bambanglipuro
# Processing Record 19 of Set 7 | svetlogorsk
# Processing Record 20 of Set 7 | merauke
# Processing Record 21 of Set 7 | manzhouli
# Processing Record 22 of Set 7 | durban
# Processing Record 23 of Set 7 | svetlyy
# Processing Record 24 of Set 7 | kulhudhuffushi
# Processing Record 25 of Set 7 | asfi
# Processing Record 26 of Set 7 | buala
# Processing Record 27 of Set 7 | mareeba
# Processing Record 28 of Set 7 | tabas
# Processing Record 29 of Set 7 | mandal
# Processing Record 30 of Set 7 | halifax
# Processing Record 31 of Set 7 | mbanza-ngungu
# Processing Record 32 of Set 7 | bethel
# Processing Record 33 of Set 7 | beloha
# Processing Record 34 of Set 7 | jejuri
# Processing Record 35 of Set 7 | nantucket
# Processing Record 36 of Set 7 | adre
# Processing Record 37 of Set 7 | theodoriana
# Processing Record 38 of Set 7 | provideniya
# Processing Record 39 of Set 7 | yenagoa
# Processing Record 40 of Set 7 | northam
# Processing Record 41 of Set 7 | paita
# Processing Record 42 of Set 7 | krasnoselkup
# Processing Record 43 of Set 7 | mednogorsk
# Processing Record 44 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 7 | loreto
# Processing Record 46 of Set 7 | karratha
# Processing Record 47 of Set 7 | turmalina
# Processing Record 48 of Set 7 | palu
# Processing Record 49 of Set 7 | matrei
# City not found. Skipping...
# Processing Record 50 of Set 7 | vanimo
# Processing Record 1 of Set 8 | fougamou
# Processing Record 2 of Set 8 | indianola
# Processing Record 3 of Set 8 | lata
# Processing Record 4 of Set 8 | turayf
# Processing Record 5 of Set 8 | loja
# Processing Record 6 of Set 8 | dongli
# Processing Record 7 of Set 8 | kirakira
# Processing Record 8 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 8 | nador
# Processing Record 10 of Set 8 | ust-kuyga
# Processing Record 11 of Set 8 | salalah
# Processing Record 12 of Set 8 | ambulu
# Processing Record 13 of Set 8 | mayo
# Processing Record 14 of Set 8 | riyadh
# Processing Record 15 of Set 8 | progreso
# Processing Record 16 of Set 8 | witu
# Processing Record 17 of Set 8 | coroata
# Processing Record 18 of Set 8 | ormond beach
# Processing Record 19 of Set 8 | mildura
# Processing Record 20 of Set 8 | clyde river
# Processing Record 21 of Set 8 | santa flavia
# Processing Record 22 of Set 8 | alta floresta
# Processing Record 23 of Set 8 | wamba
# Processing Record 24 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 8 | maldonado
# Processing Record 26 of Set 8 | berdigestyakh
# Processing Record 27 of Set 8 | candawaga
# City not found. Skipping...
# Processing Record 28 of Set 8 | barstow
# Processing Record 29 of Set 8 | semme
# Processing Record 30 of Set 8 | yilan
# Processing Record 31 of Set 8 | istok
# Processing Record 32 of Set 8 | skibbereen
# Processing Record 33 of Set 8 | san vicente
# Processing Record 34 of Set 8 | rockland
# Processing Record 35 of Set 8 | bryan
# Processing Record 36 of Set 8 | darhan
# Processing Record 37 of Set 8 | bowling green
# Processing Record 38 of Set 8 | lagos
# Processing Record 39 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 40 of Set 8 | alofi
# Processing Record 41 of Set 8 | isabela
# Processing Record 42 of Set 8 | privolzhye
# Processing Record 43 of Set 8 | lompoc
# Processing Record 44 of Set 8 | pangody
# Processing Record 45 of Set 8 | winslow
# Processing Record 46 of Set 8 | araouane
# Processing Record 47 of Set 8 | alberdi
# Processing Record 48 of Set 8 | urumqi
# Processing Record 49 of Set 8 | navirai
# Processing Record 50 of Set 8 | kupang
# Processing Record 1 of Set 9 | yuxia
# Processing Record 2 of Set 9 | agstafa
# City not found. Skipping...
# Processing Record 3 of Set 9 | tambilil
# Processing Record 4 of Set 9 | springbok
# Processing Record 5 of Set 9 | binzhou
# Processing Record 6 of Set 9 | sorong
# Processing Record 7 of Set 9 | yulara
# Processing Record 8 of Set 9 | borba
# Processing Record 9 of Set 9 | corralillo
# Processing Record 10 of Set 9 | havre-saint-pierre
# Processing Record 11 of Set 9 | sharjah
# Processing Record 12 of Set 9 | hobyo
# Processing Record 13 of Set 9 | mazara del vallo
# Processing Record 14 of Set 9 | valparaiso
# Processing Record 15 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 9 | puerto narino
# Processing Record 17 of Set 9 | lasa
# Processing Record 18 of Set 9 | parfino
# Processing Record 19 of Set 9 | aden
# Processing Record 20 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 9 | iquitos
# Processing Record 22 of Set 9 | nagua
# Processing Record 23 of Set 9 | mindelo
# Processing Record 24 of Set 9 | esna
# Processing Record 25 of Set 9 | kuala pilah
# Processing Record 26 of Set 9 | vardo
# Processing Record 27 of Set 9 | prieska
# Processing Record 28 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 29 of Set 9 | sanchor
# Processing Record 30 of Set 9 | ribeira brava
# Processing Record 31 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 9 | keflavik
# Processing Record 33 of Set 9 | soldatskaya
# Processing Record 34 of Set 9 | juegang
# Processing Record 35 of Set 9 | homer
# Processing Record 36 of Set 9 | kupino
# Processing Record 37 of Set 9 | plettenberg bay
# Processing Record 38 of Set 9 | puerto madero
# Processing Record 39 of Set 9 | shestakovo
# Processing Record 40 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 41 of Set 9 | altamira
# Processing Record 42 of Set 9 | leh
# Processing Record 43 of Set 9 | singapore
# Processing Record 44 of Set 9 | acatlan
# Processing Record 45 of Set 9 | westport
# Processing Record 46 of Set 9 | itoman
# Processing Record 47 of Set 9 | aykhal
# Processing Record 48 of Set 9 | panaba
# Processing Record 49 of Set 9 | mangai
# Processing Record 50 of Set 9 | koila
# Processing Record 1 of Set 10 | honiara
# Processing Record 2 of Set 10 | hoceni
# Processing Record 3 of Set 10 | quatre cocos
# Processing Record 4 of Set 10 | muros
# Processing Record 5 of Set 10 | ust-nera
# Processing Record 6 of Set 10 | ko samui
# Processing Record 7 of Set 10 | fredericksburg
# Processing Record 8 of Set 10 | opuwo
# Processing Record 9 of Set 10 | vega de alatorre
# Processing Record 10 of Set 10 | luderitz
# Processing Record 11 of Set 10 | kirando
# Processing Record 12 of Set 10 | haines junction
# Processing Record 13 of Set 10 | lahat
# Processing Record 14 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 10 | humberto de campos
# Processing Record 16 of Set 10 | popondetta
# Processing Record 17 of Set 10 | half moon bay
# Processing Record 18 of Set 10 | hervey bay
# Processing Record 19 of Set 10 | eskil
# Processing Record 20 of Set 10 | saint-joseph
# Processing Record 21 of Set 10 | snyder
# Processing Record 22 of Set 10 | bartica
# Processing Record 23 of Set 10 | kagadi
# Processing Record 24 of Set 10 | alyangula
# Processing Record 25 of Set 10 | maralal
# Processing Record 26 of Set 10 | najran
# Processing Record 27 of Set 10 | puqi
# Processing Record 28 of Set 10 | boa vista
# Processing Record 29 of Set 10 | brae
# Processing Record 30 of Set 10 | la ronge
# Processing Record 31 of Set 10 | garlasco
# Processing Record 32 of Set 10 | barra do garcas
# Processing Record 33 of Set 10 | pangai
# Processing Record 34 of Set 10 | ayabe
# Processing Record 35 of Set 10 | sarai mir
# Processing Record 36 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 37 of Set 10 | touros
# Processing Record 38 of Set 10 | hvolsvollur
# Processing Record 39 of Set 10 | naregal
# Processing Record 40 of Set 10 | lethem
# Processing Record 41 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 10 | namibe
# Processing Record 43 of Set 10 | sioux lookout
# Processing Record 44 of Set 10 | ayr
# Processing Record 45 of Set 10 | hirara
# Processing Record 46 of Set 10 | san carlos de bariloche
# Processing Record 47 of Set 10 | xai-xai
# Processing Record 48 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 10 | hasaki
# Processing Record 50 of Set 10 | teya
# Processing Record 1 of Set 11 | miraflores
# Processing Record 2 of Set 11 | valdivia
# Processing Record 3 of Set 11 | aasiaat
# Processing Record 4 of Set 11 | sawakin
# Processing Record 5 of Set 11 | siverek
# Processing Record 6 of Set 11 | oranjestad
# Processing Record 7 of Set 11 | san felipe
# Processing Record 8 of Set 11 | labuan
# Processing Record 9 of Set 11 | asbury park
# Processing Record 10 of Set 11 | codogno
# Processing Record 11 of Set 11 | key largo
# Processing Record 12 of Set 11 | yeppoon
# Processing Record 13 of Set 11 | srostki
# Processing Record 14 of Set 11 | tiznit
# Processing Record 15 of Set 11 | santa rosa
# Processing Record 16 of Set 11 | praia
# Processing Record 17 of Set 11 | aktyubinskiy
# Processing Record 18 of Set 11 | uddevalla
# Processing Record 19 of Set 11 | porangatu
# Processing Record 20 of Set 11 | soe
# Processing Record 21 of Set 11 | edd
# Processing Record 22 of Set 11 | searcy
# Processing Record 23 of Set 11 | ambon
# Processing Record 24 of Set 11 | bukachacha
# Processing Record 25 of Set 11 | la sarre
# Processing Record 26 of Set 11 | muzhappilangad
# City not found. Skipping...
# Processing Record 27 of Set 11 | iqaluit
# Processing Record 28 of Set 11 | xucheng
# Processing Record 29 of Set 11 | eirunepe
# Processing Record 30 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 11 | amga
# Processing Record 32 of Set 11 | anse-bertrand
# Processing Record 33 of Set 11 | pisco
# Processing Record 34 of Set 11 | sola
# Processing Record 35 of Set 11 | avanigadda
# Processing Record 36 of Set 11 | rorvik
# Processing Record 37 of Set 11 | broken hill
# Processing Record 38 of Set 11 | colomi
# Processing Record 39 of Set 11 | balasheyka
# Processing Record 40 of Set 11 | dunedin
# Processing Record 41 of Set 11 | leningradskiy
# Processing Record 42 of Set 11 | metro
# Processing Record 43 of Set 11 | jaguarao
# Processing Record 44 of Set 11 | kruisfontein
# Processing Record 45 of Set 11 | mezen
# Processing Record 46 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 47 of Set 11 | horta
# Processing Record 48 of Set 11 | nam tha
# City not found. Skipping...
# Processing Record 49 of Set 11 | nybro
# Processing Record 50 of Set 11 | margate
# Processing Record 1 of Set 12 | tongzi
# Processing Record 2 of Set 12 | raga
# Processing Record 3 of Set 12 | awjilah
# Processing Record 4 of Set 12 | rio cuarto
# Processing Record 5 of Set 12 | rakitnoye
# Processing Record 6 of Set 12 | nalut
# Processing Record 7 of Set 12 | novyy urengoy
# Processing Record 8 of Set 12 | riohacha
# Processing Record 9 of Set 12 | anloga
# Processing Record 10 of Set 12 | boguchany
# Processing Record 11 of Set 12 | oistins
# Processing Record 12 of Set 12 | mayahi
# Processing Record 13 of Set 12 | solnechnyy
# Processing Record 14 of Set 12 | dudinka
# Processing Record 15 of Set 12 | lavrentiya
# Processing Record 16 of Set 12 | wenzhou
# Processing Record 17 of Set 12 | macia
# Processing Record 18 of Set 12 | morrope
# Processing Record 19 of Set 12 | picos
# Processing Record 20 of Set 12 | havelock
# Processing Record 21 of Set 12 | sandovo
# Processing Record 22 of Set 12 | pando
# Processing Record 23 of Set 12 | baghdad
# Processing Record 24 of Set 12 | talcahuano
# Processing Record 25 of Set 12 | yumen
# Processing Record 26 of Set 12 | mendi
# Processing Record 27 of Set 12 | bogashevo
# Processing Record 28 of Set 12 | namtsy
# Processing Record 29 of Set 12 | ahuimanu
# Processing Record 30 of Set 12 | bud
# Processing Record 31 of Set 12 | cafarnaum
# Processing Record 32 of Set 12 | tilichiki
# Processing Record 33 of Set 12 | karamken
# City not found. Skipping...
# Processing Record 34 of Set 12 | bad freienwalde
# Processing Record 35 of Set 12 | guarapari
# Processing Record 36 of Set 12 | marawi
# Processing Record 37 of Set 12 | grand gaube
# Processing Record 38 of Set 12 | norsup
# Processing Record 39 of Set 12 | huanren
# Processing Record 40 of Set 12 | viedma
# Processing Record 41 of Set 12 | kumluca
# Processing Record 42 of Set 12 | seevetal
# Processing Record 43 of Set 12 | nekrasovka
# Processing Record 44 of Set 12 | jaisalmer
# Processing Record 45 of Set 12 | derbent
# Processing Record 46 of Set 12 | flinders
# Processing Record 47 of Set 12 | llanes
# Processing Record 48 of Set 12 | roma
# Processing Record 49 of Set 12 | agha jari
# City not found. Skipping...
# Processing Record 50 of Set 12 | de aar
# Processing Record 1 of Set 13 | praya
# Processing Record 2 of Set 13 | massakory
# Processing Record 3 of Set 13 | meghraj
# Processing Record 4 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 13 | honningsvag
# Processing Record 6 of Set 13 | port blair
# Processing Record 7 of Set 13 | linxia
# Processing Record 8 of Set 13 | khryashchevka
# Processing Record 9 of Set 13 | husavik
# Processing Record 10 of Set 13 | kavieng
# Processing Record 11 of Set 13 | nadym
# Processing Record 12 of Set 13 | kawalu
# Processing Record 13 of Set 13 | atar
# Processing Record 14 of Set 13 | beira
# Processing Record 15 of Set 13 | vung tau
# Processing Record 16 of Set 13 | nizhniy tsasuchey
# Processing Record 17 of Set 13 | taoudenni
# Processing Record 18 of Set 13 | ngawen
# Processing Record 19 of Set 13 | shizunai
# Processing Record 20 of Set 13 | san cristobal
# Processing Record 21 of Set 13 | takestan
# Processing Record 22 of Set 13 | kesennuma
# City not found. Skipping...
# Processing Record 23 of Set 13 | lagoa
# Processing Record 24 of Set 13 | sao joao da barra
# Processing Record 25 of Set 13 | hambantota
# Processing Record 26 of Set 13 | anchorage
# Processing Record 27 of Set 13 | prestea
# Processing Record 28 of Set 13 | belmonte
# Processing Record 29 of Set 13 | topchikha
# Processing Record 30 of Set 13 | el dorado
# Processing Record 31 of Set 13 | samarai
# Processing Record 32 of Set 13 | shimoda
# Processing Record 33 of Set 13 | taybad
# Processing Record 34 of Set 13 | smithers
# Processing Record 35 of Set 13 | maryborough
# Processing Record 36 of Set 13 | tamasane
# Processing Record 37 of Set 13 | storm lake
# Processing Record 38 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 13 | nabire
# Processing Record 40 of Set 13 | talara
# Processing Record 41 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 13 | straumen
# Processing Record 43 of Set 13 | burgersdorp
# Processing Record 44 of Set 13 | evensk
# Processing Record 45 of Set 13 | marzuq
# Processing Record 46 of Set 13 | novovasylivka
# Processing Record 47 of Set 13 | burica
# City not found. Skipping...
# Processing Record 48 of Set 13 | camapua
# Processing Record 49 of Set 13 | suez
# Processing Record 50 of Set 13 | slave lake
# Processing Record 1 of Set 14 | scalloway
# City not found. Skipping...
# Processing Record 2 of Set 14 | tocopilla
# Processing Record 3 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 14 | severnyy-kospashskiy
# Processing Record 5 of Set 14 | reguengos de monsaraz
# Processing Record 6 of Set 14 | hofn
# Processing Record 7 of Set 14 | rock springs
# Processing Record 8 of Set 14 | palestine
# Processing Record 9 of Set 14 | arrecife
# Processing Record 10 of Set 14 | shimoni
# Processing Record 11 of Set 14 | male
# Processing Record 12 of Set 14 | brownwood
# Processing Record 13 of Set 14 | ndioum
# Processing Record 14 of Set 14 | basoko
# Processing Record 15 of Set 14 | melission
# Processing Record 16 of Set 14 | teeli
# Processing Record 17 of Set 14 | maua
# Processing Record 18 of Set 14 | ngunguru
# Processing Record 19 of Set 14 | virginia beach
# Processing Record 20 of Set 14 | cisternino
# Processing Record 21 of Set 14 | san roque
# Processing Record 22 of Set 14 | komsomolskiy
# Processing Record 23 of Set 14 | oktyabrskiy
# Processing Record 24 of Set 14 | nagamangala
# Processing Record 25 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 26 of Set 14 | morro bay
# Processing Record 27 of Set 14 | leshukonskoye
# Processing Record 28 of Set 14 | tay ninh
# Processing Record 29 of Set 14 | severnoye
# Processing Record 30 of Set 14 | coro
# Processing Record 31 of Set 14 | tazovskiy
# Processing Record 32 of Set 14 | pitimbu
# Processing Record 33 of Set 14 | srednekolymsk
# Processing Record 34 of Set 14 | abalak
# Processing Record 35 of Set 14 | maneadero
# Processing Record 36 of Set 14 | changji
# Processing Record 37 of Set 14 | oxford
# Processing Record 38 of Set 14 | gizo
# Processing Record 39 of Set 14 | leona vicario
# Processing Record 40 of Set 14 | kant
# Processing Record 41 of Set 14 | marshall
# Processing Record 42 of Set 14 | pocone
# Processing Record 43 of Set 14 | gorin
# Processing Record 44 of Set 14 | katobu
# Processing Record 45 of Set 14 | auki
# Processing Record 46 of Set 14 | kikwit
# Processing Record 47 of Set 14 | bentiu
# Processing Record 48 of Set 14 | rochester
# Processing Record 49 of Set 14 | alamosa
# Processing Record 50 of Set 14 | morant bay
# Processing Record 1 of Set 15 | daimiel
# Processing Record 2 of Set 15 | maragogi
# Processing Record 3 of Set 15 | pitsunda
# Processing Record 4 of Set 15 | siparia
# Processing Record 5 of Set 15 | ponta delgada
# Processing Record 6 of Set 15 | nizhniy ingash
# Processing Record 7 of Set 15 | richards bay
# Processing Record 8 of Set 15 | fort wellington
# Processing Record 9 of Set 15 | doha
# Processing Record 10 of Set 15 | kourou
# Processing Record 11 of Set 15 | ryabovo
# Processing Record 12 of Set 15 | riachao das neves
# Processing Record 13 of Set 15 | wenatchee
# Processing Record 14 of Set 15 | yanam
# Processing Record 15 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 15 | atasu
# Processing Record 17 of Set 15 | isperih
# Processing Record 18 of Set 15 | severo-yeniseyskiy
# Processing Record 19 of Set 15 | churapcha
# Processing Record 20 of Set 15 | khani
# Processing Record 21 of Set 15 | mehran
# Processing Record 22 of Set 15 | morondava
# Processing Record 23 of Set 15 | kieta
# Processing Record 24 of Set 15 | stroitel
# Processing Record 25 of Set 15 | teguldet
# Processing Record 26 of Set 15 | mormugao
# Processing Record 27 of Set 15 | winnemucca
# Processing Record 28 of Set 15 | prince rupert
# Processing Record 29 of Set 15 | yuma
# Processing Record 30 of Set 15 | buchanan
# Processing Record 31 of Set 15 | vestmannaeyjar
# Processing Record 32 of Set 15 | dombas
# Processing Record 33 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 15 | bauchi
# Processing Record 35 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 15 | oktyabrskoye
# Processing Record 37 of Set 15 | beloeil
# Processing Record 38 of Set 15 | nyurba
# Processing Record 39 of Set 15 | acayucan
# Processing Record 40 of Set 15 | waipawa
# Processing Record 41 of Set 15 | altay
# Processing Record 42 of Set 15 | suoyarvi
# Processing Record 43 of Set 15 | nemuro
# Processing Record 44 of Set 15 | pasni
# Processing Record 45 of Set 15 | eureka
# Processing Record 46 of Set 15 | hengshui
# Processing Record 47 of Set 15 | narsaq
# Processing Record 48 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 15 | miri
# Processing Record 50 of Set 15 | asosa
# Processing Record 1 of Set 16 | qasigiannguit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town      ZA -33.9258   18.4232     57.88        90          75
# 1           Arlit      NE  18.7369    7.3853     97.20        21         100
# 2      Kaitangata      NZ -46.2817  169.8464     37.58        85          97
# 3           Nioro      GM  13.3500  -15.7500     77.61        87         100
# 4         Varkaus      FI  62.3153   27.8730     64.51        97         100
# 5  Port Elizabeth      ZA -33.9180   25.5701     58.10        81         100
# 6           Akyab      MM  20.1500   92.9000     80.80        86         100
# 7          Barrow      US  71.2906 -156.7887     34.45        91         100
# 8        Katsuura      JP  35.1333  140.3000     84.31        88         100
# 9   Sao Sebastiao      BR -23.7600  -45.4097     69.39        73           2
#
#    Wind Speed   Current Description
# 0        8.99  heavy intensity rain
# 1       11.25       overcast clouds
# 2        9.08       overcast clouds
# 3        7.02       overcast clouds
# 4        4.54       overcast clouds
# 5        8.46       overcast clouds
# 6        2.66       overcast clouds
# 7        9.86       overcast clouds
# 8       23.13       overcast clouds
# 9        1.86             clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
